# %%
pip install opendartreader # DART API를 손쉽게 불러와서 쓸수 있는 패키지입니다.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opendartreader in /usr/local/lib/python3.9/dist-packages (0.2.3)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.9/dist-packages (from opendartreader) (1.5.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from opendartreader) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from opendartreader) (4.11.2)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from opendartreader) (2.27.1)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.9/dist-packages (from opendartreader) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19.2->opendartreader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19.2->opendartreader) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19.2->opendartreader) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (2.0.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->opendartreader) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from requests-file->opendartreader) (1.16.0)

# %%
pip install --upgrade opendartreader #이미 설치돼 있다면 업그레이드
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opendartreader in /usr/local/lib/python3.9/dist-packages (0.2.3)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.9/dist-packages (from opendartreader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from opendartreader) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from opendartreader) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from opendartreader) (4.9.2)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.9/dist-packages (from opendartreader) (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19.2->opendartreader) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19.2->opendartreader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19.2->opendartreader) (2022.7.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.3.0->opendartreader) (2022.12.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->opendartreader) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from requests-file->opendartreader) (1.16.0)

# %%
import OpenDartReader

# 주석(Remark)
# ==== 0. 객체 생성 ==== 주석(remark)
# 객체 생성 (API KEY 지정) 
api_key = '07c7f341baf16d656e73b618ab3ffe0bedc7cf68'
#key는 각자 받은 것으로 하시면 됩니다.

dart = OpenDartReader(api_key) # 들어가서 데이터를 보는것이다.

# %%
# == 1. 공시정보 검색 ==
# 삼성전자의 정기보고서('A') 2020년
dart.list('005930', kind='A', start='2022-01-01', end='2022-09-01')
# Out:
#   corp_code corp_name stock_code corp_cls        report_nm        rcept_no  \
# 0  00126380      삼성전자     005930        Y  반기보고서 (2022.06)  20220816001711
# 1  00126380      삼성전자     005930        Y  분기보고서 (2022.03)  20220516001751
# 2  00126380      삼성전자     005930        Y  사업보고서 (2021.12)  20220308000798
#
#   flr_nm  rcept_dt rm
# 0   삼성전자  20220816
# 1   삼성전자  20220516
# 2   삼성전자  20220308  연

# %%
# 기업의 개황정보
dart.company('005930')
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '한종희, 경계현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.samsung.com/sec',
#  'ir_url': '',
#  'phn_no': '02-2255-0114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %%
# 회사명에 삼성전자가 포함된 회사들에 대한 개황정보
dart.company_by_name('삼성전자')
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00258999',
#   'corp_name': '삼성전자 서비스주식회사',
#   'corp_name_eng': 'SAMSUNNG ELECTRONICS SERVICE CO., LTD',
#   'stock_name': '삼성전자서비스',
#   'stock_code': '',
#   'ceo_nm': '송봉섭',
#   'corp_cls': 'E',
#   'jurir_no': '1301110049139',
#   'bizr_no': '1248158485',
#   'adres': '경기도 수원시 영통구 삼성로 290 (원천동)',
#   'hm_url': 'www.samsungsvc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-2177',
#   'fax_no': '031-270-2106',
#   'induty_code': '95',
#   'est_dt': '19981027',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01345812',
#   'corp_name': '삼성전자서비스씨에스 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SERVICE CUSTOMER SATISFACTION., LTD.',
#   'stock_name': '삼성전자서비스씨에스',
#   'stock_code': '',
#   'ceo_nm': '이명옥',
#   'corp_cls': 'E',
#   'jurir_no': '1358110352541',
#   'bizr_no': '7898701103',
#   'adres': '경기도 수원시 영통구 중부대로 324 (매탄동, KT동수원지사)',
#   'hm_url': '',
#   'ir_url': '',
#   'phn_no': '031-210-8914',
#   'fax_no': '031-8006-1009',
#   'induty_code': '75991',
#   'est_dt': '20181105',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00252074',
#   'corp_name': '삼성전자판매 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SALES Co., Ltd.',
#   'stock_name': '삼성전자판매',
#   'stock_code': '',
#   'ceo_nm': '이평우',
#   'corp_cls': 'E',
#   'jurir_no': '1801110210300',
#   'bizr_no': '6178117517',
#   'adres': '경기도 성남시 분당구 황새울로 340',
#   'hm_url': 'www.samsungsales.co.kr',
#   'ir_url': '',
#   'phn_no': '02-3460-6656',
#   'fax_no': '02-3460-6802',
#   'induty_code': '47320',
#   'est_dt': '19960711',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00126380',
#   'corp_name': '삼성전자(주)',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#   'stock_name': '삼성전자',
#   'stock_code': '005930',
#   'ceo_nm': '한종희, 경계현',
#   'corp_cls': 'Y',
#   'jurir_no': '1301110006246',
#   'bizr_no': '1248100998',
#   'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#   'hm_url': 'www.samsung.com/sec',
#   'ir_url': '',
#   'phn_no': '02-2255-0114',
#   'fax_no': '031-200-7538',
#   'induty_code': '264',
#   'est_dt': '19690113',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00366997',
#   'corp_name': '삼성전자로지텍(주)',
#   'corp_name_eng': 'SELC.CO.,LTD',
#   'stock_name': '삼성전자로지텍',
#   'stock_code': '',
#   'ceo_nm': '최윤범',
#   'corp_cls': 'E',
#   'jurir_no': '1301110046797',
#   'bizr_no': '1248155381',
#   'adres': '경기도 수원시 영통구 삼성로 129',
#   'hm_url': 'www.selc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-3488',
#   'fax_no': '031-270-3673',
#   'induty_code': '52999',
#   'est_dt': '19980401',
#   'acc_mt': '12'}]

# %%
dart.company_by_name('LG전자')
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00401731',
#   'corp_name': 'LG전자(주)',
#   'corp_name_eng': 'LG ELECTRONICS INC.',
#   'stock_name': 'LG전자',
#   'stock_code': '066570',
#   'ceo_nm': '조주완, 배두용 (각자 대표이사)',
#   'corp_cls': 'Y',
#   'jurir_no': '1101112487050',
#   'bizr_no': '1078614075',
#   'adres': '서울특별시 영등포구  여의대로 128 LG트윈타워',
#   'hm_url': 'www.lge.co.kr',
#   'ir_url': 'www.lge.co.kr/company/investor/presentation#com-tabs01',
#   'phn_no': '02-3777-1114',
#   'fax_no': '3777-3428',
#   'induty_code': '264',
#   'est_dt': '20020401',
#   'acc_mt': '12'}]

# %%
# 삼성전자 사업보고서 (2018.12) 원문 텍스트
xml_text = dart.document('20190401004781')

# %%
# ==== 2. 사업보고서 ====
# 삼성전자(005930), 배당관련 사항, 2022년
dart.report('005930', '배당', 2022)
# Out:
#           rcept_no corp_cls corp_code corp_name              se      thstrm  \
# 0   20230307000542        Y  00126380      삼성전자       주당액면가액(원)         100
# 1   20230307000542        Y  00126380      삼성전자  (연결)당기순이익(백만원)  54,730,018
# 2   20230307000542        Y  00126380      삼성전자  (별도)당기순이익(백만원)  25,418,778
# 3   20230307000542        Y  00126380      삼성전자    (연결)주당순이익(원)       8,057
# 4   20230307000542        Y  00126380      삼성전자    현금배당금총액(백만원)   9,809,438
# 5   20230307000542        Y  00126380      삼성전자    주식배당금총액(백만원)           -
# 6   20230307000542        Y  00126380      삼성전자   (연결)현금배당성향(%)       17.90
# 7   20230307000542        Y  00126380      삼성전자      현금배당수익률(%)        2.50
# 8   20230307000542        Y  00126380      삼성전자      현금배당수익률(%)        2.70
# 9   20230307000542        Y  00126380      삼성전자      주식배당수익률(%)           -
# 10  20230307000542        Y  00126380      삼성전자      주식배당수익률(%)           -
# 11  20230307000542        Y  00126380      삼성전자     주당 현금배당금(원)       1,444
# 12  20230307000542        Y  00126380      삼성전자     주당 현금배당금(원)       1,445
# 13  20230307000542        Y  00126380      삼성전자      주당 주식배당(주)           -
# 14  20230307000542        Y  00126380      삼성전자      주당 주식배당(주)           -
#
#         frmtrm        lwfr stock_knd
# 0          100         100       NaN
# 1   39,243,791  26,090,846       NaN
# 2   30,970,954  15,615,018       NaN
# 3        5,777       3,841       NaN
# 4    9,809,438  20,338,075       NaN
# 5            -           -       NaN
# 6        25.00       78.00       NaN
# 7         1.80        4.00       보통주
# 8         2.00        4.20       우선주
# 9            -           -       보통주
# 10           -           -       우선주
# 11       1,444       2,994       보통주
# 12       1,445       2,995       우선주
# 13           -           -       보통주
# 14           -           -       우선주

# %%
# ==== 2. 사업보고서 ====
# 삼성전자(005930), 배당관련 사항, 2022년
dart.report('005930', '배당', 2022)
# Out:
#           rcept_no corp_cls corp_code corp_name              se      thstrm  \
# 0   20230307000542        Y  00126380      삼성전자       주당액면가액(원)         100
# 1   20230307000542        Y  00126380      삼성전자  (연결)당기순이익(백만원)  54,730,018
# 2   20230307000542        Y  00126380      삼성전자  (별도)당기순이익(백만원)  25,418,778
# 3   20230307000542        Y  00126380      삼성전자    (연결)주당순이익(원)       8,057
# 4   20230307000542        Y  00126380      삼성전자    현금배당금총액(백만원)   9,809,438
# 5   20230307000542        Y  00126380      삼성전자    주식배당금총액(백만원)           -
# 6   20230307000542        Y  00126380      삼성전자   (연결)현금배당성향(%)       17.90
# 7   20230307000542        Y  00126380      삼성전자      현금배당수익률(%)        2.50
# 8   20230307000542        Y  00126380      삼성전자      현금배당수익률(%)        2.70
# 9   20230307000542        Y  00126380      삼성전자      주식배당수익률(%)           -
# 10  20230307000542        Y  00126380      삼성전자      주식배당수익률(%)           -
# 11  20230307000542        Y  00126380      삼성전자     주당 현금배당금(원)       1,444
# 12  20230307000542        Y  00126380      삼성전자     주당 현금배당금(원)       1,445
# 13  20230307000542        Y  00126380      삼성전자      주당 주식배당(주)           -
# 14  20230307000542        Y  00126380      삼성전자      주당 주식배당(주)           -
#
#         frmtrm        lwfr stock_knd
# 0          100         100       NaN
# 1   39,243,791  26,090,846       NaN
# 2   30,970,954  15,615,018       NaN
# 3        5,777       3,841       NaN
# 4    9,809,438  20,338,075       NaN
# 5            -           -       NaN
# 6        25.00       78.00       NaN
# 7         1.80        4.00       보통주
# 8         2.00        4.20       우선주
# 9            -           -       보통주
# 10           -           -       우선주
# 11       1,444       2,994       보통주
# 12       1,445       2,995       우선주
# 13           -           -       보통주
# 14           -           -       우선주

# %%
# 서울반도체(046890), 최대주주 관한 사항, 2018년
dart.report('046890', '최대주주', 2018)
# Out:
#          rcept_no corp_cls corp_code corp_name stock_knd   nm relate  \
# 0  20190401003450        K  00130763     서울반도체       보통주  이정훈     본인
# 1  20190401003450        K  00130763     서울반도체       보통주  이민호  특수관계인
# 2  20190401003450        K  00130763     서울반도체       보통주  이민규  특수관계인
# 3  20190401003450        K  00130763     서울반도체       보통주    계    NaN
# 4  20190401003450        K  00130763     서울반도체         -    계    NaN
#
#   bsis_posesn_stock_co bsis_posesn_stock_qota_rt trmend_posesn_stock_co  \
# 0            9,749,744                     16.72              9,749,744
# 1            5,076,358                      8.71              5,076,358
# 2            5,076,358                      8.71              5,076,358
# 3           19,902,460                     34.13             19,902,460
# 4                    -                         -                      -
#
#   trmend_posesn_stock_qota_rt rm
# 0                       16.72  -
# 1                        8.71  -
# 2                        8.71  -
# 3                       34.13  -
# 4                           -  -

# %%
# 서울반도체(046890), 임원 관한 사항, 2018년
dart.report('046890', '임원', 2018)
# Out:
#          rcept_no corp_cls corp_code corp_name   nm sexdstn   birth_ym  \
# 0  20190401003450        K  00130763     서울반도체  이정훈       남  1953년 01월
# 1  20190401003450        K  00130763     서울반도체  박형건       남  1960년 04월
# 2  20190401003450        K  00130763     서울반도체  장정식       남  1955년 07월
# 3  20190401003450        K  00130763     서울반도체  오명민       남  1977년 01월
#
#        ofcps rgist_exctv_at fte_at      chrg_job  \
# 0  대표이사\n 사장           등기임원     상근          경영총괄
# 1       사외이사           등기임원    비상근  사외이사/\n 감사위원
# 2       사외이사           등기임원    비상근  사외이사/\n 감사위원
# 3       사외이사           등기임원    비상근  사외이사/\n 감사위원
#
#                                          main_career mxmm_shrholdr_relate  \
# 0                  - 삼신전기(주) 부사장\n- 서울반도체(주) 대표이사(現)                   본인
# 1  - 연세대경영학학사/서울대경영학석사수료\n- 국세청 정보공개심의위원회 위원\n- 우...                    -
# 2  - 서울대 공업화학과 학사/석사\n- Case Western Reserve 대학 공...                    -
# 3  - 서울대 원예학과 학사/석사\n- Kansas 주립대학 원예학과 박사\n- 충북대...                    -
#
#   hffc_pd  tenure_end_on
# 0  1992년~  2019년 03월 28일
# 1  2016년~  2020년 03월 27일
# 2  2018년~  2020년 03월 27일
# 3  2018년~  2020년 03월 27일

# %%
# ==== 3. 상장기업 재무정보 ====
# 삼성전자 2018 재무제표 
dart.finstate('삼성전자', 2018) # 사업보고서
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 1   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 2   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 3   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 4   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 5   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 6   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 7   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 8   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 9   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 10  20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 11  20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 12  20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 13  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 14  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 15  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 16  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 17  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 18  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 19  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 20  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 21  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 22  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 23  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 24  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 25  20190401004781      11011      2018  00126380     005930    OFS    재무제표
#
#    sj_div  sj_nm  account_nm  ...                thstrm_dt  \
# 0      BS  재무상태표        유동자산  ...            2018.12.31 현재
# 1      BS  재무상태표       비유동자산  ...            2018.12.31 현재
# 2      BS  재무상태표        자산총계  ...            2018.12.31 현재
# 3      BS  재무상태표        유동부채  ...            2018.12.31 현재
# 4      BS  재무상태표       비유동부채  ...            2018.12.31 현재
# 5      BS  재무상태표        부채총계  ...            2018.12.31 현재
# 6      BS  재무상태표         자본금  ...            2018.12.31 현재
# 7      BS  재무상태표       이익잉여금  ...            2018.12.31 현재
# 8      BS  재무상태표        자본총계  ...            2018.12.31 현재
# 9      IS  손익계산서         매출액  ...  2018.01.01 ~ 2018.12.31
# 10     IS  손익계산서        영업이익  ...  2018.01.01 ~ 2018.12.31
# 11     IS  손익계산서  법인세차감전 순이익  ...  2018.01.01 ~ 2018.12.31
# 12     IS  손익계산서       당기순이익  ...  2018.01.01 ~ 2018.12.31
# 13     BS  재무상태표        유동자산  ...            2018.12.31 현재
# 14     BS  재무상태표       비유동자산  ...            2018.12.31 현재
# 15     BS  재무상태표        자산총계  ...            2018.12.31 현재
# 16     BS  재무상태표        유동부채  ...            2018.12.31 현재
# 17     BS  재무상태표       비유동부채  ...            2018.12.31 현재
# 18     BS  재무상태표        부채총계  ...            2018.12.31 현재
# 19     BS  재무상태표         자본금  ...            2018.12.31 현재
# 20     BS  재무상태표       이익잉여금  ...            2018.12.31 현재
# 21     BS  재무상태표        자본총계  ...            2018.12.31 현재
# 22     IS  손익계산서         매출액  ...  2018.01.01 ~ 2018.12.31
# 23     IS  손익계산서        영업이익  ...  2018.01.01 ~ 2018.12.31
# 24     IS  손익계산서  법인세차감전 순이익  ...  2018.01.01 ~ 2018.12.31
# 25     IS  손익계산서       당기순이익  ...  2018.01.01 ~ 2018.12.31
#
#           thstrm_amount frmtrm_nm                frmtrm_dt  \
# 0   174,697,424,000,000    제 49 기            2017.12.31 현재
# 1   164,659,820,000,000    제 49 기            2017.12.31 현재
# 2   339,357,244,000,000    제 49 기            2017.12.31 현재
# 3    69,081,510,000,000    제 49 기            2017.12.31 현재
# 4    22,522,557,000,000    제 49 기            2017.12.31 현재
# 5    91,604,067,000,000    제 49 기            2017.12.31 현재
# 6       897,514,000,000    제 49 기            2017.12.31 현재
# 7   242,698,956,000,000    제 49 기            2017.12.31 현재
# 8   247,753,177,000,000    제 49 기            2017.12.31 현재
# 9   243,771,415,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 10   58,886,669,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 11   61,159,958,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 12   44,344,857,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 13   80,039,455,000,000    제 49 기            2017.12.31 현재
# 14  138,981,902,000,000    제 49 기            2017.12.31 현재
# 15  219,021,357,000,000    제 49 기            2017.12.31 현재
# 16   43,145,053,000,000    제 49 기            2017.12.31 현재
# 17    2,888,179,000,000    제 49 기            2017.12.31 현재
# 18   46,033,232,000,000    제 49 기            2017.12.31 현재
# 19      897,514,000,000    제 49 기            2017.12.31 현재
# 20  166,555,532,000,000    제 49 기            2017.12.31 현재
# 21  172,988,125,000,000    제 49 기            2017.12.31 현재
# 22  170,381,870,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 23   43,699,451,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 24   44,398,855,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 25   32,815,127,000,000    제 49 기  2017.01.01 ~ 2017.12.31
#
#           frmtrm_amount bfefrmtrm_nm             bfefrmtrm_dt  \
# 0   146,982,464,000,000       제 48 기            2016.12.31 현재
# 1   154,769,626,000,000       제 48 기            2016.12.31 현재
# 2   301,752,090,000,000       제 48 기            2016.12.31 현재
# 3    67,175,114,000,000       제 48 기            2016.12.31 현재
# 4    20,085,548,000,000       제 48 기            2016.12.31 현재
# 5    87,260,662,000,000       제 48 기            2016.12.31 현재
# 6       897,514,000,000       제 48 기            2016.12.31 현재
# 7   215,811,200,000,000       제 48 기            2016.12.31 현재
# 8   214,491,428,000,000       제 48 기            2016.12.31 현재
# 9   239,575,376,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 10   53,645,038,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 11   56,195,967,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 12   42,186,747,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 13   70,155,189,000,000       제 48 기            2016.12.31 현재
# 14  128,086,171,000,000       제 48 기            2016.12.31 현재
# 15  198,241,360,000,000       제 48 기            2016.12.31 현재
# 16   44,495,084,000,000       제 48 기            2016.12.31 현재
# 17    2,176,501,000,000       제 48 기            2016.12.31 현재
# 18   46,671,585,000,000       제 48 기            2016.12.31 현재
# 19      897,514,000,000       제 48 기            2016.12.31 현재
# 20  150,928,724,000,000       제 48 기            2016.12.31 현재
# 21  151,569,775,000,000       제 48 기            2016.12.31 현재
# 22  161,915,007,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 23   34,857,091,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 24   36,533,552,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 25   28,800,837,000,000       제 48 기  2016.01.01 ~ 2016.12.31
#
#        bfefrmtrm_amount ord currency
# 0   141,429,704,000,000   1      KRW
# 1   120,744,620,000,000   3      KRW
# 2   262,174,324,000,000   5      KRW
# 3    54,704,095,000,000   7      KRW
# 4    14,507,196,000,000   9      KRW
# 5    69,211,291,000,000  11      KRW
# 6       897,514,000,000  13      KRW
# 7   193,086,317,000,000  17      KRW
# 8   192,963,033,000,000  21      KRW
# 9   201,866,745,000,000  23      KRW
# 10   29,240,672,000,000  25      KRW
# 11   30,713,652,000,000  27      KRW
# 12   22,726,092,000,000  29      KRW
# 13   69,981,128,000,000   2      KRW
# 14  104,821,831,000,000   4      KRW
# 15  174,802,959,000,000   6      KRW
# 16   34,076,122,000,000   8      KRW
# 17    3,180,075,000,000  10      KRW
# 18   37,256,197,000,000  12      KRW
# 19      897,514,000,000  15      KRW
# 20  140,747,574,000,000  19      KRW
# 21  137,546,762,000,000  22      KRW
# 22  133,947,204,000,000  24      KRW
# 23   13,647,436,000,000  26      KRW
# 24   14,725,074,000,000  28      KRW
# 25   11,579,749,000,000  30      KRW
#
# [26 rows x 21 columns]

# %%
# 삼성전자 2018Q1 재무제표
dart.finstate('삼성전자', 2018, reprt_code='11013')
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 1   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 2   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 3   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 4   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 5   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 6   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 7   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 8   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 9   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 10  20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 11  20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 12  20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 13  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 14  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 15  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 16  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 17  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 18  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 19  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 20  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 21  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 22  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 23  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 24  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 25  20180515001699      11013      2018  00126380     005930    OFS    재무제표
#
#    sj_div  sj_nm  account_nm   thstrm_nm                thstrm_dt  \
# 0      BS  재무상태표        유동자산  제 50 기1분기말            2018.03.31 현재
# 1      BS  재무상태표       비유동자산  제 50 기1분기말            2018.03.31 현재
# 2      BS  재무상태표        자산총계  제 50 기1분기말            2018.03.31 현재
# 3      BS  재무상태표        유동부채  제 50 기1분기말            2018.03.31 현재
# 4      BS  재무상태표       비유동부채  제 50 기1분기말            2018.03.31 현재
# 5      BS  재무상태표        부채총계  제 50 기1분기말            2018.03.31 현재
# 6      BS  재무상태표         자본금  제 50 기1분기말            2018.03.31 현재
# 7      BS  재무상태표       이익잉여금  제 50 기1분기말            2018.03.31 현재
# 8      BS  재무상태표        자본총계  제 50 기1분기말            2018.03.31 현재
# 9      IS  손익계산서         매출액   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 10     IS  손익계산서        영업이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 11     IS  손익계산서  법인세차감전 순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 12     IS  손익계산서       당기순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 13     BS  재무상태표        유동자산  제 50 기1분기말            2018.03.31 현재
# 14     BS  재무상태표       비유동자산  제 50 기1분기말            2018.03.31 현재
# 15     BS  재무상태표        자산총계  제 50 기1분기말            2018.03.31 현재
# 16     BS  재무상태표        유동부채  제 50 기1분기말            2018.03.31 현재
# 17     BS  재무상태표       비유동부채  제 50 기1분기말            2018.03.31 현재
# 18     BS  재무상태표        부채총계  제 50 기1분기말            2018.03.31 현재
# 19     BS  재무상태표         자본금  제 50 기1분기말            2018.03.31 현재
# 20     BS  재무상태표       이익잉여금  제 50 기1분기말            2018.03.31 현재
# 21     BS  재무상태표        자본총계  제 50 기1분기말            2018.03.31 현재
# 22     IS  손익계산서         매출액   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 23     IS  손익계산서        영업이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 24     IS  손익계산서  법인세차감전 순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 25     IS  손익계산서       당기순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
#
#           thstrm_amount  frmtrm_nm                frmtrm_dt  \
# 0   154,941,953,000,000    제 49 기말            2017.12.31 현재
# 1   157,531,160,000,000    제 49 기말            2017.12.31 현재
# 2   312,473,113,000,000    제 49 기말            2017.12.31 현재
# 3    68,298,586,000,000    제 49 기말            2017.12.31 현재
# 4    20,914,647,000,000    제 49 기말            2017.12.31 현재
# 5    89,213,233,000,000    제 49 기말            2017.12.31 현재
# 6       897,514,000,000    제 49 기말            2017.12.31 현재
# 7   222,485,398,000,000    제 49 기말            2017.12.31 현재
# 8   223,259,880,000,000    제 49 기말            2017.12.31 현재
# 9    60,563,714,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 10   15,642,170,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 11   16,175,907,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 12   11,688,544,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 13   72,370,085,000,000    제 49 기말            2017.12.31 현재
# 14  132,836,079,000,000    제 49 기말            2017.12.31 현재
# 15  205,206,164,000,000    제 49 기말            2017.12.31 현재
# 16   47,168,741,000,000    제 49 기말            2017.12.31 현재
# 17    1,842,051,000,000    제 49 기말            2017.12.31 현재
# 18   49,010,792,000,000    제 49 기말            2017.12.31 현재
# 19      897,514,000,000    제 49 기말            2017.12.31 현재
# 20  154,284,538,000,000    제 49 기말            2017.12.31 현재
# 21  156,195,372,000,000    제 49 기말            2017.12.31 현재
# 22   42,606,978,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 23   11,200,897,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 24   11,568,977,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 25    8,452,458,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
#
#           frmtrm_amount ord currency   thstrm_add_amount   frmtrm_add_amount
# 0   146,982,464,000,000   1      KRW                 NaN                 NaN
# 1   154,769,626,000,000   3      KRW                 NaN                 NaN
# 2   301,752,090,000,000   5      KRW                 NaN                 NaN
# 3    67,175,114,000,000   7      KRW                 NaN                 NaN
# 4    20,085,548,000,000   9      KRW                 NaN                 NaN
# 5    87,260,662,000,000  11      KRW                 NaN                 NaN
# 6       897,514,000,000  13      KRW                 NaN                 NaN
# 7   215,811,200,000,000  17      KRW                 NaN                 NaN
# 8   214,491,428,000,000  21      KRW                 NaN                 NaN
# 9    50,547,526,000,000  23      KRW  60,563,714,000,000  50,547,526,000,000
# 10    9,898,361,000,000  25      KRW  15,642,170,000,000   9,898,361,000,000
# 11   10,164,576,000,000  27      KRW  16,175,907,000,000  10,164,576,000,000
# 12    7,684,354,000,000  29      KRW  11,688,544,000,000   7,684,354,000,000
# 13   70,155,189,000,000   2      KRW                 NaN                 NaN
# 14  128,086,171,000,000   4      KRW                 NaN                 NaN
# 15  198,241,360,000,000   6      KRW                 NaN                 NaN
# 16   44,495,084,000,000   8      KRW                 NaN                 NaN
# 17    2,176,501,000,000  10      KRW                 NaN                 NaN
# 18   46,671,585,000,000  12      KRW                 NaN                 NaN
# 19      897,514,000,000  15      KRW                 NaN                 NaN
# 20  150,928,724,000,000  19      KRW                 NaN                 NaN
# 21  151,569,775,000,000  22      KRW                 NaN                 NaN
# 22   34,578,524,000,000  24      KRW  42,606,978,000,000  34,578,524,000,000
# 23    5,675,571,000,000  26      KRW  11,200,897,000,000   5,675,571,000,000
# 24    6,309,744,000,000  28      KRW  11,568,977,000,000   6,309,744,000,000
# 25    4,873,767,000,000  30      KRW   8,452,458,000,000   4,873,767,000,000

# %%
# 여러종목 한번에
dart.finstate('00126380,00164779,00164742', 2021)
dart.finstate('005930, 000660, 005380', 2021)
dart.finstate('삼성전자, SK하이닉스, 현대자동차', 2021)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 1   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 2   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 3   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 4   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# ..             ...        ...       ...       ...        ...    ...     ...
# 72  20220322000590      11011      2021  00164779     000660    OFS    재무제표
# 73  20220322000590      11011      2021  00164779     000660    OFS    재무제표
# 74  20220322000590      11011      2021  00164779     000660    OFS    재무제표
# 75  20220322000590      11011      2021  00164779     000660    OFS    재무제표
# 76  20220322000590      11011      2021  00164779     000660    OFS    재무제표
#
#    sj_div  sj_nm  account_nm  ...                thstrm_dt  \
# 0      BS  재무상태표        유동자산  ...            2021.12.31 현재
# 1      BS  재무상태표       비유동자산  ...            2021.12.31 현재
# 2      BS  재무상태표        자산총계  ...            2021.12.31 현재
# 3      BS  재무상태표        유동부채  ...            2021.12.31 현재
# 4      BS  재무상태표       비유동부채  ...            2021.12.31 현재
# ..    ...    ...         ...  ...                      ...
# 72     BS  재무상태표        자본총계  ...            2021.12.31 현재
# 73     IS  손익계산서         매출액  ...  2021.01.01 ~ 2021.12.31
# 74     IS  손익계산서        영업이익  ...  2021.01.01 ~ 2021.12.31
# 75     IS  손익계산서  법인세차감전 순이익  ...  2021.01.01 ~ 2021.12.31
# 76     IS  손익계산서       당기순이익  ...  2021.01.01 ~ 2021.12.31
#
#           thstrm_amount frmtrm_nm                frmtrm_dt  \
# 0   218,163,185,000,000    제 52 기            2020.12.31 현재
# 1   208,457,973,000,000    제 52 기            2020.12.31 현재
# 2   426,621,158,000,000    제 52 기            2020.12.31 현재
# 3    88,117,133,000,000    제 52 기            2020.12.31 현재
# 4    33,604,094,000,000    제 52 기            2020.12.31 현재
# ..                  ...       ...                      ...
# 72   58,737,614,000,000    제 73 기            2020.12.31 현재
# 73   41,557,337,000,000    제 73 기  2020.01.01 ~ 2020.12.31
# 74   12,183,360,000,000    제 73 기  2020.01.01 ~ 2020.12.31
# 75   13,130,428,000,000    제 73 기  2020.01.01 ~ 2020.12.31
# 76    9,567,226,000,000    제 73 기  2020.01.01 ~ 2020.12.31
#
#           frmtrm_amount bfefrmtrm_nm             bfefrmtrm_dt  \
# 0   198,215,579,000,000       제 51 기            2019.12.31 현재
# 1   180,020,139,000,000       제 51 기            2019.12.31 현재
# 2   378,235,718,000,000       제 51 기            2019.12.31 현재
# 3    75,604,351,000,000       제 51 기            2019.12.31 현재
# 4    26,683,351,000,000       제 51 기            2019.12.31 현재
# ..                  ...          ...                      ...
# 72   49,574,304,000,000       제 72 기            2019.12.31 현재
# 73   30,524,987,000,000       제 72 기  2019.01.01 ~ 2019.12.31
# 74    4,545,877,000,000       제 72 기  2019.01.01 ~ 2019.12.31
# 75    5,650,034,000,000       제 72 기  2019.01.01 ~ 2019.12.31
# 76    4,217,841,000,000       제 72 기  2019.01.01 ~ 2019.12.31
#
#        bfefrmtrm_amount ord currency
# 0   181,385,260,000,000   1      KRW
# 1   171,179,237,000,000   3      KRW
# 2   352,564,497,000,000   5      KRW
# 3    63,782,764,000,000   7      KRW
# 4    25,901,312,000,000   9      KRW
# ..                  ...  ..      ...
# 72   46,036,908,000,000  22      KRW
# 73   25,320,755,000,000  24      KRW
# 74    1,989,700,000,000  26      KRW
# 75    1,803,514,000,000  28      KRW
# 76    1,476,981,000,000  30      KRW
#
# [77 rows x 21 columns]

# %%
# 단일기업 전체 재무제표 (삼성전자 2018 전체 재무제표)
dart.finstate_all('005930', 2021)
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20220308000798      11011      2021  00126380     BS  재무상태표
# 1    20220308000798      11011      2021  00126380     BS  재무상태표
# 2    20220308000798      11011      2021  00126380     BS  재무상태표
# 3    20220308000798      11011      2021  00126380     BS  재무상태표
# 4    20220308000798      11011      2021  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 181  20220308000798      11011      2021  00126380    SCE  자본변동표
# 182  20220308000798      11011      2021  00126380    SCE  자본변동표
# 183  20220308000798      11011      2021  00126380    SCE  자본변동표
# 184  20220308000798      11011      2021  00126380    SCE  자본변동표
# 185  20220308000798      11011      2021  00126380    SCE  자본변동표
#
#                                             account_id       account_nm  \
# 0                              ifrs-full_CurrentAssets             유동자산
# 1                     ifrs-full_CashAndCashEquivalents         현금및현금성자산
# 2    dart_ShortTermDepositsNotClassifiedAsCashEquiv...           단기금융상품
# 3                                         -표준계정코드 미사용-      단기상각후원가금융자산
# 4    ifrs-full_CurrentFinancialAssetsAtFairValueThr...  단기당기손익-공정가치금융자산
# ..                                                 ...              ...
# 181                                   ifrs-full_Equity             기말자본
# 182                                   ifrs-full_Equity             기말자본
# 183                                   ifrs-full_Equity             기말자본
# 184                                   ifrs-full_Equity             기말자본
# 185                                   ifrs-full_Equity             기말자본
#
#                             account_detail thstrm_nm    thstrm_amount  \
# 0                                        -    제 53 기  218163185000000
# 1                                        -    제 53 기   39031415000000
# 2                                        -    제 53 기   81708986000000
# 3                                        -    제 53 기    3369034000000
# 4                                        -    제 53 기      40757000000
# ..                                     ...       ...              ...
# 181          자본 [member]|지배기업 소유주지분|기타자본항목    제 53 기   -2128473000000
# 182    자본 [member]|지배기업 소유주지분|매각예정분류기타자본항목    제 53 기                0
# 183  자본 [member]|지배기업 소유주지분|이익잉여금 [member]    제 53 기  293064763000000
# 184    자본 [member]|지배기업 소유주지분|자본금 [member]    제 53 기     897514000000
# 185         자본 [member]|지배기업 소유주지분|주식발행초과금    제 53 기    4403893000000
#
#     frmtrm_nm    frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord currency  \
# 0      제 52 기  198215579000000       제 51 기  181385260000000   1      KRW
# 1      제 52 기   29382578000000       제 51 기   26885999000000   2      KRW
# 2      제 52 기   92441703000000       제 51 기   76252052000000   3      KRW
# 3      제 52 기    2757111000000       제 51 기    3914216000000   4      KRW
# 4      제 52 기      71451000000       제 51 기    1727436000000   5      KRW
# ..        ...              ...          ...              ...  ..      ...
# 181    제 52 기   -8687155000000       제 51 기   -4968829000000  13      KRW
# 182    제 52 기     -12132000000       제 51 기                0  13      KRW
# 183    제 52 기  271068211000000       제 51 기  254582894000000  13      KRW
# 184    제 52 기     897514000000       제 51 기     897514000000  13      KRW
# 185    제 52 기    4403893000000       제 51 기    4403893000000  13      KRW
#
#     thstrm_add_amount
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 181               NaN
# 182               NaN
# 183               NaN
# 184               NaN
# 185               NaN
#
# [186 rows x 18 columns]

# %%
# 재무제표 XBRL 원본 파일 저장 (삼성전자 2018 사업보고서)
dart.finstate_xml('20190401004781', save_as='삼성전자_2018_사업보고서_XBRL.zip')
# Out:
# True

# %%
# XBRL 표준계정과목체계(계정과목)
dart.xbrl_taxonomy('BS1')
# Out:
#     sj_div   bsns_de                                         account_id  \
# 0      BS1  20180701          ifrs_StatementOfFinancialPositionAbstract
# 1      BS1  20180701                                ifrs_AssetsAbstract
# 2      BS1  20180701                                 ifrs_CurrentAssets
# 3      BS1  20180701                        ifrs_CashAndCashEquivalents
# 4      BS1  20180701                                          ifrs_Cash
# ..     ...       ...                                                ...
# 514    BS1  20180701                             dart_VoluntaryReserves
# 515    BS1  20180701  dart_RetainedEarningsBeforeAppropriationsAccum...
# 516    BS1  20180701                       ifrs_NoncontrollingInterests
# 517    BS1  20180701                                        ifrs_Equity
# 518    BS1  20180701                          ifrs_EquityAndLiabilities
#
#                                             account_nm         label_kor  \
# 0                 StatementOfFinancialPositionAbstract  재무상태표 [abstract]
# 1                                       AssetsAbstract     자산 [abstract]
# 2                                        CurrentAssets              유동자산
# 3                               CashAndCashEquivalents          현금및현금성자산
# 4                                                 Cash                현금
# ..                                                 ...               ...
# 514                                  VoluntaryReserves             임의적립금
# 515  RetainedEarningsBeforeAppropriationsAccumulate...  미처분이익잉여금(미처리결손금)
# 516                            NoncontrollingInterests             비지배지분
# 517                                             Equity              자본총계
# 518                               EquityAndLiabilities           자본과부채총계
#
#                                              label_eng  \
# 0           Statement of financial position [abstract]
# 1                                    Assets [abstract]
# 2                                       Current assets
# 3                            Cash and cash equivalents
# 4                                                 Cash
# ..                                                 ...
# 514                                 Voluntary Reserves
# 515  Retained earnings before appropriations(accumu...
# 516                          Non-controlling interests
# 517                                       Total equity
# 518                       Total equity and liabilities
#
#                                               ifrs_ref data_tp
# 0                                                          NaN
# 1                                                          NaN
# 2                                    K-IFRS 1001 문단 60       X
# 3              K-IFRS 1001 문단 54 (9),K-IFRS 1007 문단 45       X
# 4              K-IFRS 1001 문단 54 (9),K-IFRS 1007 문단 45       X
# ..                                                 ...     ...
# 514  K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K...       X
# 515  K-IFRS 1001 문단 54 (18),K-IFRS 1001 문단 78 (5),K...       X
# 516                             K-IFRS 1001 문단 54 (17)       X
# 517                                                        NaN
# 518                                                        NaN
#
# [519 rows x 8 columns]

# %%
# 임원ㆍ주요주주 소유보고 (종목코드, 종목명, 고유번호 모두 지정 가능)
dart.major_shareholders_exec('005930')
# Out:
#            rcept_no    rcept_dt corp_code corp_name repror isu_exctv_rgist_at  \
# 0    20210427000593  2021-04-28  00126380      삼성전자    우경구              비등기임원
# 1    20210430000481  2021-04-30  00126380      삼성전자    안규리               등기임원
# 2    20210430001364  2021-04-30  00126380      삼성전자    김승일              비등기임원
# 3    20210503000523  2021-05-03  00126380      삼성전자    이건희                  -
# 4    20210503000533  2021-05-03  00126380      삼성전자    이재용              비등기임원
# ..              ...         ...       ...       ...    ...                ...
# 228  20230302000431  2023-03-02  00126380      삼성전자    안재용              비등기임원
# 229  20230316000646  2023-03-16  00126380      삼성전자    안재용              비등기임원
# 230  20230324000884  2023-03-24  00126380      삼성전자    경계현               등기임원
# 231  20230406002362  2023-04-06  00126380      삼성전자    김이태              비등기임원
# 232  20230412002146  2023-04-12  00126380      삼성전자    김이태              비등기임원
#
#     isu_exctv_ofcps isu_main_shrholdr sp_stock_lmp_cnt sp_stock_lmp_irds_cnt  \
# 0                상무                 -              670                -1,330
# 1              사외이사                 -            3,000                   100
# 2                상무                 -              254                   254
# 3                 -           사실상지배주주                0          -249,893,100
# 4               부회장           사실상지배주주       97,551,953            55,531,803
# ..              ...               ...              ...                   ...
# 228              상무                 -              250                   250
# 229              상무                 -              500                   250
# 230         대표이사 사장                 -           21,050                 3,000
# 231             부사장                 -            1,800                 1,800
# 232             부사장                 -                0                -1,800
#
#     sp_stock_lmp_rate sp_stock_lmp_irds_rate
# 0                0.00                   0.00
# 1                0.00                   0.00
# 2                0.00                   0.00
# 3                0.00                  -3.41
# 4                1.44                   0.87
# ..                ...                    ...
# 228              0.00                   0.00
# 229              0.00                   0.00
# 230              0.00                   0.00
# 231              0.00                   0.00
# 232                 0                  -0.00
#
# [233 rows x 12 columns]

# %%
# ==== 5. 확장 기능 ====
# 지정한 날짜의 공시목록 전체
dart.list_date('2020-02-03')
# Out:
# /usr/local/lib/python3.9/dist-packages/OpenDartReader/dart.py:168: UserWarning: list_date() is deprecated. use list_date_ex()
#   warnings.warn('list_date() is deprecated. use list_date_ex()')

# %%
# 지정한 날짜의 공시목록 전체 (시간 정보 포함)
dart.list_date_ex('2020-01-03')
# Out:
#                rcept_dt corp_cls corp_name        rcept_no  \
# 0   2020-01-03 18:40:00        유       풀무원  20200103800678
# 1   2020-01-03 18:26:00        코     이엠앤아이  20200103000641
# 2   2020-01-03 18:25:00        코     이엠앤아이  20200103000648
# 3   2020-01-03 18:25:00        코     이엠앤아이  20200103000645
# 4   2020-01-03 18:20:00        넥      렌딩머신  20200103600668
# ..                  ...      ...       ...             ...
# 576 2020-01-03 07:30:00        기    동원관광개발  20200102000464
# 577 2020-01-03 07:30:00        코     디에스앤엘  20200102000466
# 578 2020-01-03 07:30:00        코     디에스앤엘  20200102000465
# 579 2020-01-03 07:30:00        코   아이쓰리시스템  20200102000459
# 580 2020-01-03 07:30:00        코     유비벨록스  20200102000460
#
#                  report_nm    flr_nm rm
# 0          장래사업ㆍ경영계획(공정공시)       풀무원  유
# 1      [기재정정]주요사항보고서(감자결정)     이엠앤아이  정
# 2    [기재정정]주요사항보고서(유상증자결정)     이엠앤아이  정
# 3    [기재정정]주요사항보고서(유상증자결정)     이엠앤아이  정
# 4                거래처와의거래중단      렌딩머신  넥
# ..                     ...       ... ..
# 576        감사보고서 (2019.09)  예교지성회계법인
# 577    [기재정정]의결권대리행사권유참고서류     디에스앤엘  정
# 578         [기재정정]주주총회소집공고     디에스앤엘  정
# 579    임원ㆍ주요주주특정증권등소유상황보고서       김병혁
# 580      주식등의대량보유상황보고서(일반)       이흥복
#
# [581 rows x 7 columns]

# %%
# 개별 문서 제목과 URL
rcp_no = '20190401004781' # 삼성전자 2018년 사업보고서
dart.sub_docs(rcp_no)
# Out:
#                           title  \
# 0                     사 업 보 고 서
# 1                【 대표이사 등의 확인 】
# 2                     I. 회사의 개요
# 3                     1. 회사의 개요
# 4                     2. 회사의 연혁
# 5                   3. 자본금 변동사항
# 6                   4. 주식의 총수 등
# 7                     5. 의결권 현황
# 8                6. 배당에 관한 사항 등
# 9                    II. 사업의 내용
# 10               III. 재무에 관한 사항
# 11                    1. 요약재무정보
# 12                    2. 연결재무제표
# 13                 3. 연결재무제표 주석
# 14                      4. 재무제표
# 15                   5. 재무제표 주석
# 16              6. 기타 재무에 관한 사항
# 17          IV. 이사의 경영진단 및 분석의견
# 18               V. 감사인의 감사의견 등
# 19      VI. 이사회 등 회사의 기관에 관한 사항
# 20                1. 이사회에 관한 사항
# 21               2. 감사제도에 관한 사항
# 22         3. 주주의 의결권 행사에 관한 사항
# 23               VII. 주주에 관한 사항
# 24       VIII. 임원 및 직원 등에 관한 사항
# 25               1. 임원 및 직원의 현황
# 26                  2. 임원의 보수 등
# 27            IX. 계열회사 등에 관한 사항
# 28              X. 이해관계자와의 거래내용
# 29  XI. 그 밖에 투자자 보호를 위하여 필요한 사항
# 30                  【 전문가의 확인 】
# 31                   1. 전문가의 확인
# 32                2. 전문가와의 이해관계
#
#                                                   url
# 0   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 1   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 2   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 3   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 4   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 5   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 6   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 7   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 8   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 9   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 10  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 11  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 12  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 13  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 14  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 15  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 16  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 17  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 18  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 19  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 20  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 21  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 22  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 23  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 24  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 25  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 26  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 27  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 28  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 29  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 30  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 31  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 32  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...

# %%
# 제목이 잘 매치되는 순서로 소트
dart.sub_docs('20190401004781', match='사업의 내용')
# Out:
#                           title  \
# 9                    II. 사업의 내용
# 2                     I. 회사의 개요
# 3                     1. 회사의 개요
# 4                     2. 회사의 연혁
# 28              X. 이해관계자와의 거래내용
# 1                【 대표이사 등의 확인 】
# 18               V. 감사인의 감사의견 등
# 0                     사 업 보 고 서
# 31                   1. 전문가의 확인
# 17          IV. 이사의 경영진단 및 분석의견
# 6                   4. 주식의 총수 등
# 30                  【 전문가의 확인 】
# 26                  2. 임원의 보수 등
# 32                2. 전문가와의 이해관계
# 19      VI. 이사회 등 회사의 기관에 관한 사항
# 25               1. 임원 및 직원의 현황
# 14                      4. 재무제표
# 22         3. 주주의 의결권 행사에 관한 사항
# 12                    2. 연결재무제표
# 11                    1. 요약재무정보
# 7                     5. 의결권 현황
# 15                   5. 재무제표 주석
# 5                   3. 자본금 변동사항
# 13                 3. 연결재무제표 주석
# 20                1. 이사회에 관한 사항
# 8                6. 배당에 관한 사항 등
# 23               VII. 주주에 관한 사항
# 10               III. 재무에 관한 사항
# 21               2. 감사제도에 관한 사항
# 16              6. 기타 재무에 관한 사항
# 27            IX. 계열회사 등에 관한 사항
# 24       VIII. 임원 및 직원 등에 관한 사항
# 29  XI. 그 밖에 투자자 보호를 위하여 필요한 사항
#
#                                                   url
# 9   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 2   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 3   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 4   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 28  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 1   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 18  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 0   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 31  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 17  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 6   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 30  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 26  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 32  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 19  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 25  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 14  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 22  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 12  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 11  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 7   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 15  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 5   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 13  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 20  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 8   http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 23  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 10  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 21  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 16  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 27  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 24  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 29  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...

# %%
# 첨부 문서 제목과 URL
dart.attach_docs(rcp_no)
# Out:
#                         title  \
# 0            2019.04.01 감사보고서
# 1         2019.04.01 감사의감사보고서
# 2  2019.04.01 내부감시장치에대한감사의의견서
# 3    2019.04.01 내부회계관리제도운영보고서
# 4          2019.04.01 연결감사보고서
# 5            2019.04.01 영업보고서
# 6               2019.04.01 정관
#
#                                                  url
# 0  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 1  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 2  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 3  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 4  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 5  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 6  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...

# %%
# 제목이 잘 매치되는 순서로 소트
dart.attach_docs(rcp_no, match='감사보고서')
# Out:
#                         title  \
# 0            2019.04.01 감사보고서
# 4          2019.04.01 연결감사보고서
# 1         2019.04.01 감사의감사보고서
# 5            2019.04.01 영업보고서
# 3    2019.04.01 내부회계관리제도운영보고서
# 2  2019.04.01 내부감시장치에대한감사의의견서
# 6               2019.04.01 정관
#
#                                                  url
# 0  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 4  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 1  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 5  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 3  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 2  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 6  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
