# %% [markdown]
# 회귀 알고리즘과 모델규제

# %% [markdown]
# https://www.notion.so/mrobo2016/1-6c74b774847a465baee99c1662ec4cc5

# %% [markdown]
# ![162f11ff-4bb5-499d-b796-382305dc97c9-MJS_Yellow_perch_8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![67942d11-4e4c-4b6c-9ae2-4f86dd60099e-Image_91.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #1-1 데이터 입력

# %%
import numpy as np
#데이터를 배열(array)로 입력하기 위해서 numpy라는 알고리즘을 np라는 이름으로 해서 입력합니다.

# %%
#농어의 길이 입력 
perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])

# %%
#입력값 확인
perch_length
# Out:
# array([ 8.4, 13.7, 15. , 16.2, 17.4, 18. , 18.7, 19. , 19.6, 20. , 21. ,
#        21. , 21. , 21.3, 22. , 22. , 22. , 22. , 22. , 22.5, 22.5, 22.7,
#        23. , 23.5, 24. , 24. , 24.6, 25. , 25.6, 26.5, 27.3, 27.5, 27.5,
#        27.5, 28. , 28.7, 30. , 32.8, 34.5, 35. , 36.5, 36. , 37. , 37. ,
#        39. , 39. , 39. , 40. , 40. , 40. , 40. , 42. , 43. , 43. , 43.5,
#        44. ])

# %%
print(perch_length)
# Out:
# [ 8.4 13.7 15.  16.2 17.4 18.  18.7 19.  19.6 20.  21.  21.  21.  21.3
#  22.  22.  22.  22.  22.  22.5 22.5 22.7 23.  23.5 24.  24.  24.6 25.
#  25.6 26.5 27.3 27.5 27.5 27.5 28.  28.7 30.  32.8 34.5 35.  36.5 36.
#  37.  37.  39.  39.  39.  40.  40.  40.  40.  42.  43.  43.  43.5 44. ]

# %%
#농어 숫자 확인 
len(perch_length)
# Out:
# 56

# %%
#농어의 무게
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

# %%
#입력값 확인
perch_weight
# Out:
# array([   5.9,   32. ,   40. ,   51.5,   70. ,  100. ,   78. ,   80. ,
#          85. ,   85. ,  110. ,  115. ,  125. ,  130. ,  120. ,  120. ,
#         130. ,  135. ,  110. ,  130. ,  150. ,  145. ,  150. ,  170. ,
#         225. ,  145. ,  188. ,  180. ,  197. ,  218. ,  300. ,  260. ,
#         265. ,  250. ,  250. ,  300. ,  320. ,  514. ,  556. ,  840. ,
#         685. ,  700. ,  700. ,  690. ,  900. ,  650. ,  820. ,  850. ,
#         900. , 1015. ,  820. , 1100. , 1000. , 1100. , 1000. , 1000. ])

# %%
#농어 숫자 확인 
len(perch_weight)
#숫자가 맞는지 확인, 총 56개가 돼야 한다.
# Out:
# 56

# %% [markdown]
# # #1-2 데이터를 한번에 보기 : 산점도

# %%
import matplotlib.pyplot as plt
#차트를 그리는 함수를 plt로 이름을 줄여서 불러옵니다.

# %%
plt.scatter(perch_length, perch_weight)
#농어의 길이를 x축 농어의 무게를 y축으로 하는 차트를 그립니다.

# %%
#공분산
a1=np.cov(perch_length,perch_weight)

a=np.cov(perch_length,perch_weight)[0,1]
#[0,1]를 빼고 입력하면 행렬로 나온다.
print(a)

#상관계수 
b=np.corrcoef(perch_length,perch_weight)[0,1]
#[0,1]를 빼고 입력하면 행렬로 나온다.
print(b)
# Out:
# 3006.4326493506487
# 0.9586558679968437

# %%
a1
# Out:
# array([[8.13904935e+01, 3.00643265e+03],
#        [3.00643265e+03, 1.20838077e+05]])

# %%
plt.scatter(perch_length, perch_weight)
#농어의 길이를 x축 농어의 무게를 y축으로 하는 차트를 그립니다.
plt.xlabel('length')
#차트의 x축을 길이(length)라고 이름을 붙입니다.
plt.ylabel('weight')
#차트의 y축을 무게(weight)라고 이름을 붙입니다.
# Out:
# Text(0, 0.5, 'weight')

# %%
plt.scatter(perch_weight, perch_length)
#농어의 길이를 y축 농어의 무게를 x축으로 하는 차트를 그립니다.

# %%
plt.scatter(perch_length, perch_weight)
#농어의 길이를 x축 농어의 무게를 y축으로 하는 차트를 그립니다.
plt.xlabel('length')
#차트의 x축을 길이(length)라고 이름을 붙입니다.
plt.ylabel('weight')
#차트의 y축을 무게(weight)라고 이름을 붙입니다.
plt.show()
#차트를 출력합니다.

# %%
import numpy as np

#공분산
a=np.cov(perch_length, perch_weight)[0,1]
#[0,1]를 빼고 입력하면 행렬로 나온다.
print(a)

#상관계수 
b=np.corrcoef(perch_length, perch_weight)[0,1]
#[0,1]를 빼고 입력하면 행렬로 나온다.
print(b)
# Out:
# 3006.4326493506487
# 0.9586558679968437

# %% [markdown]
# ## 1-3 머신러닝 코드 구현을 위한 데이터 셑 분리

# %%
#농어의 데이터를 훈련세트/테스트 세트로 구분하기 위해서 이 기능이 train_test_split을 불러옵니다. 
from sklearn.model_selection import train_test_split

#훈련을 위한 데이터, 검증(test)를 위한 데이터(길이)와 무게(target)로 데이터를 나누고, 랜덤42이라고 지정해 이를 실행합니다. 
train_input,test_input,train_target,test_target= train_test_split(perch_length, perch_weight, random_state=42)

# %%
#1,2,3,4로 구성된 원소를 배열(array)형태로 지정합니다.
test_array=np.array([1,2,3,4])

# %%
#배열(array)형태로 어떻게 저장됐는지 보겠습니다. 
test_array
# Out:
# array([1, 2, 3, 4])

# %%
#4x1 행렬과 같은 것이군요
print(test_array.shape)
# Out:
# (4,)

# %%
#배열을 2x2로 바꿉니다.
test_array1=test_array.reshape(2,2)

# %%
#바꾼 배열의 형태를 볼까요?
print(test_array1.shape)
# Out:
# (2, 2)

# %%
#바뀐 배열을 보도록 하겠습니다.
test_array1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#배열의 크기에 -1를 입력할 경우 : 나머지를 원소의 개수로 채운다
train_input1=train_input.reshape(-1,1)
test_input1=test_input.reshape(-1,1)
#바뀐 배열 형식을 출력한다.
print(train_input1.shape, test_input1.shape)
# Out:
# (42, 1) (14, 1)

# %%
print(train_input.shape)
# Out:
# (42,)

# %%
print(train_input)
# Out:
# [19.6 22.  18.7 17.4 36.  25.  40.  39.  43.  22.  20.  22.  24.  27.5
#  43.  40.  24.  21.  27.5 40.  32.8 26.5 36.5 13.7 22.7 15.  37.  35.
#  28.7 23.5 39.  21.  23.  22.  44.  22.5 19.  37.  22.  25.6 42.  34.5]

# %%
print(test_input1)
# Out:
# [[ 8.4]
#  [18. ]
#  [27.5]
#  [21.3]
#  [22.5]
#  [40. ]
#  [30. ]
#  [24.6]
#  [39. ]
#  [21. ]
#  [43.5]
#  [16.2]
#  [28. ]
#  [27.3]]

# %%
print(train_input1)
# Out:
# [[19.6]
#  [22. ]
#  [18.7]
#  [17.4]
#  [36. ]
#  [25. ]
#  [40. ]
#  [39. ]
#  [43. ]
#  [22. ]
#  [20. ]
#  [22. ]
#  [24. ]
#  [27.5]
#  [43. ]
#  [40. ]
#  [24. ]
#  [21. ]
#  [27.5]
#  [40. ]
#  [32.8]
#  [26.5]
#  [36.5]
#  [13.7]
#  [22.7]
#  [15. ]
#  [37. ]
#  [35. ]
#  [28.7]
#  [23.5]
#  [39. ]
#  [21. ]
#  [23. ]
#  [22. ]
#  [44. ]
#  [22.5]
#  [19. ]
#  [37. ]
#  [22. ]
#  [25.6]
#  [42. ]
#  [34.5]]

# %%
#복습, 여기까지 코드 1줄마다 실행을 누르세오 :11:21

# %% [markdown]
# ## 1-4 결정계수

# %%
from sklearn.neighbors import KNeighborsRegressor

knr=KNeighborsRegressor()

knr.fit(train_input1, train_target)
# Out:
# KNeighborsRegressor()

# %%
knr.score(test_input1, test_target)
# Out:
# 0.992809406101064

# %%
print(knr.score(test_input1, test_target))
#99%의 의미가 무엇일까요?
# Out:
# 0.992809406101064

# %% [markdown]
# ##1-5 예측해보기

# %%
#예측한 값과 실제 값의 차이를 비교하기 위해서 mean_absolute_error라는 함수를 사용함니다.
from sklearn.metrics import mean_absolute_error

#테스트 세트에 대한 예측을 합니다.
test_prediction=knr.predict(test_input1)

# %%
#테스트 세터의 평균에 대한 오차를 계산합니다. (그런데 왜 평균의 절대값을 사용했을까요?)
mae=mean_absolute_error(test_target,test_prediction)
print(mae)
# Out:
# 19.157142857142862

# %%
#해석 : 결과치에서 예측이 평균적으로 19정도 타켓과 다르다.

# %% [markdown]
# ##1-5 과대 적합 vs 과소 적합

# %%
#훈련한 모델의 결정계수를 봅니다.
print(knr.score(train_input1, train_target))
# Out:
# 0.9698823289099254

# %%
#근접점의 개수를 3개로 설정합니다. 
#근접점을 3~10까지 올려가면서 정확도 계산
knr.n_neighbors=3
#모델을 근접점 3개를 반영해 다시 훈련시킵니다.
knr.fit(train_input1, train_target)

#새롭게 훈련한 결과치의 점수를 봅니다.데이터는 훈련세트
print(knr.score(train_input1, train_target))
# Out:
# 0.9804899950518966

# %%
print(knr.score(test_input1,test_target))
#테스트 세트로 해보니까 97%
# Out:
# 0.9746459963987609

# %% [markdown]
# #근접회귀 모델로 "시뮬레이션"

# %%
#데이터 입력 중 배열(arrary)를 가지고 오기 위해 numpy를 np라고 해서 불러옵니다.
import numpy as np

# %%
#데이터를 입력
perch_length = np.array(
    [8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0]
     )
perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 
     1000.0, 1000.0]
     )

# %%
#훈련을 위해서 sklearn이라는 함수에서 train_test_split을 씁니다.(데이터 분할)
from sklearn.model_selection import train_test_split

# 훈련 세트와 테스트 세트로 나눕니다
train_input, test_input, train_target, test_target = train_test_split(
    perch_length, perch_weight, random_state=42)
# 훈련 세트와 테스트 세트를 2차원 배열로 바꿉니다
train_input1 = train_input.reshape(-1, 1)
test_input1 = test_input.reshape(-1, 1)

# %%
from sklearn.neighbors import KNeighborsRegressor

knr = KNeighborsRegressor(n_neighbors=3)
# k-최근접 이웃 회귀 모델을 훈련합니다
knr.fit(train_input1, train_target)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
print(knr.predict([[10030]]))
# Out:
# [1033.33333333]

# %% [markdown]
# * 코드 오류 발생 유형
# knr.predict([[50]])
#
# 1) knr.predict(   )안에 예측할 값을 넣는대. 50일 경우 [50] 아니라 [[50]]을 넣는다. ( [..[50]. [60]... ] 이런 식이다.)
#
# 2) 그리고 해당 명령어(knr.predic) 밖에 있는 print에서 print할 결과를 (          )안에 넣는다.

# %%
print(knr.predict([[40]]))
# Out:
# [921.66666667]

# %%
print(knr.predict([[44]]))
# Out:
# [1033.33333333]

# %%
print(knr.predict([[500]]))
# Out:
# [1033.33333333]

# %% [markdown]
# ## 실제로 무게가 1033g일까요?

# %%
#차트를 그리는 함수 실행
import matplotlib.pyplot as plt

# %%
# 50cm 농어의 이웃을 구합니다. 이웃
distances, indexes = knr.kneighbors([[50]])

# 훈련 세트의 산점도를 그립니다
plt.scatter(train_input, train_target)
# 훈련 세트 중에서 이웃 샘플만 다시 그립니다
plt.scatter(train_input[indexes], train_target[indexes], marker='D')
# 50cm 농어 데이터
plt.scatter(50, 1033, marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %% [markdown]
# ##선형회귀 모형

# %%
#선형회귀 모형을 위해서 LinearRegression이라는 함수를 불러옵니다.
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
# 선형 회귀 모델 훈련
lr.fit(train_input1, train_target)
# Out:
# LinearRegression()

# %%
# 50cm 농어에 대한 예측
print(lr.predict([[50]]))
#앞 모델의 예측값(1033g)과 비교해봅니다.
# Out:
# [1241.83860323]

# %%
print(lr.coef_, lr.intercept_)
#축의 기울기와 y절편을 봅니다.
# Out:
# [39.01714496] -709.0186449535477

# %%
# 훈련 세트의 산점도를 그립니다
plt.scatter(train_input, train_target)
# 15에서 50까지 1차 방정식 그래프를 그립니다.
# (선형으로 선을 긋고 x값을 넣으면 y값을 예측합니다.)
plt.plot([15, 50], [15*lr.coef_+lr.intercept_, 50*lr.coef_+lr.intercept_])
# 50cm 농어 데이터
plt.scatter(50, 1241.8, marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
print(lr.score(train_input1, train_target))
print(lr.score(test_input1, test_target))
#훈련용 세트로 구한 예측도와 테스트 세트로 구한 예측도를 봅니다.
# Out:
# 0.939846333997604
# 0.8247503123313558

# %% [markdown]
# ##다항회귀(비선형 회귀모형)

# %%
train_poly = np.column_stack((train_input ** 2, train_input))
test_poly = np.column_stack((test_input ** 2, test_input))
#2차 방정식으로 예측합니다. 왜 그럴까요?

# %%
print(train_poly.shape, test_poly.shape)
# Out:
# (42, 2) (14, 2)

# %%
lr = LinearRegression()
lr.fit(train_poly, train_target)

print(lr.predict([[50**2, 50]]))
#왜 50의 제곱을 모형에 집어넣을까요?
# Out:
# [1573.98423528]

# %%
print(lr.coef_, lr.intercept_)
#훈련한 모델의 기울기와 y절편을 출력
# Out:
# [  1.01433211 -21.55792498] 116.0502107827827

# %%
# 구간별 직선을 그리기 위해 15에서 49까지 정수 배열을 만듭니다
point = np.arange(15, 50)
# 훈련 세트의 산점도를 그립니다
plt.scatter(train_input, train_target)
# 15에서 49까지 2차 방정식 그래프를 그립니다
plt.plot(point, 1.01*point**2 - 21.6*point + 116.05)
# 50cm 농어 데이터
plt.scatter([50], [1574], marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
print(lr.score(train_poly, train_target))
print(lr.score(test_poly, test_target))
# Out:
# 0.9706807451768623
# 0.9775935108325122
